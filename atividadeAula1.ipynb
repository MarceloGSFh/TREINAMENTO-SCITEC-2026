# %% [markdown]
# Crie uma lista chamada valores_brutos com os números: [10, 50, 150, 20, 300].

# %%
valores_brutos = [10, 50, 150, 20, 300]

# %% [markdown]
# Crie uma função com Type Hints que precorra essa lista. Se o valor for maior que 100, coloque-o em uma nova lista chamada alertas.

# %%
alertas = []
def percorre_lista(lista1, lista2):
    num : int
    for num in valores_brutos:
        if num > 100:
            alertas.append(num)

# %% [markdown]
# No final, use um if para printar: "Sistema Seguro" (se não houver alertas) ou "Revisar valores: [lista]" (se houver).

# %%
def main():
    percorre_lista(valores_brutos, alertas)
    if alertas:
        print(f"Revisar valores: {alertas}")
    else:
        print("Sistema Seguro.")
main()
# Out:
# Revisar valores: [150, 300]
